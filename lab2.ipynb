# %%
import pandas as pd;
import matplotlib.pyplot as plt

# %%
import pandas as pd;
iris=pd.read_csv("Iris.csv")

# %%
print(iris)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# specific row
iris.iloc[105]
# Out:
# Id                          106
# SepalLengthCm               7.6
# SepalWidthCm                3.0
# PetalLengthCm               6.6
# PetalWidthCm                2.1
# Species          Iris-virginica
# Name: 105, dtype: object

# %%
# accessing spcific row
iris.iloc[56,5]
# Out:
# 'Iris-versicolor'

# %%
iris.loc[3,'SepalLengthCm']
# Out:
# 4.6

# %%
# retrieving rowss by loc method
row1 = iris.iloc[[7,9,13,17]]
print(row1)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa

# %%
# access specific row
row2=iris.iloc[4]
print(row2)
# Out:
# Id                         5
# SepalLengthCm            5.0
# SepalWidthCm             3.6
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 4, dtype: object

# %%
# check if rows have the data satisfying a condition
row3=(iris.Species=='Iris-setosa')&(iris.SepalLengthCm>=4.5)
print(row3)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
# access rows that have the data satisfying a condition
row4= (iris.loc[(iris.Species=='Iris-setosa')&(iris.SepalLengthCm>=4.5)])
print(row4)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# ...

# %%
display(row1)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa

# %%
display(row2)
# Out:
# Id                         5
# SepalLengthCm            5.0
# SepalWidthCm             3.6
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 4, dtype: object

# %%
display(row3)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
display(row4)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# ...

# %%
# import matplotlib.pyplot as plot;

# %%
# scatterplot features of Iris
iris.plot(kind="scatter",x="SepalLengthCm",y="SepalWidthCm")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
iris.plot(kind="scatter",x="PetalLengthCm",y="PetalWidthCm")
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
import seaborn as sns;

# %%
sns.jointplot(x="SepalLengthCm",y="SepalWidthCm",data=iris,size=5)

# %%
sns.jointplot(x="PetalLengthCm",y="PetalWidthCm",data=iris,size=5)

# %%
sns.FacetGrid(iris,hue="Species")\
    .map(plt.scatter,"SepalLengthCm","SepalWidthCm")\
    .add_legend()

# %%
sns.FacetGrid(iris,hue="Species")\
    .map(plt.scatter,"PetalLengthCm","PetalWidthCm")\
    .add_legend()

# %%
sns.FacetGrid(iris,hue="Species")\
    .map(plt.scatter,"PetalLengthCm","SepalLengthCm")\
    .add_legend()

# %%
sns.FacetGrid(iris,hue="Species")\
    .map(plt.scatter,"PetalLengthCm","SepalWidthCm")\
    .add_legend()

# %%
sns.FacetGrid(iris,hue="Species")\
    .map(plt.scatter,"SepalWidthCm","PetalWidthCm")\
    .add_legend()

# %%
sns.FacetGrid(iris,hue="Species")\
    .map(plt.scatter,"SepalLengthCm","PetalWidthCm")\
    .add_legend()

# %%
# plot individual feature in Seaborn through a boxplot
sns.boxplot(x="Species",y="PetalLengthCm",data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.boxplot(x="Species",y="SepalLengthCm",data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.boxplot(x="Species",y="PetalWidthCm",data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %%
sns.boxplot(x="Species",y="SepalWidthCm",data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
#
ax=sns.boxplot(x="Species",y="PetalLengthCm",data=iris)
ax=sns.stripplot(x="Species",y="PetalLengthCm",data=iris,jitter=True,edgecolor="gray")

# %%
sns.violinplot(x="Species",y="SepalWidthCm",data=iris,size=6)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.FacetGrid(iris,hue="Species")\
    .map(sns.kdeplot,"PetalLengthCm")\
    .add_legend()

# %%
sns.pairplot(iris.drop("Id",axis=1),hue="Species", size=3)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
iris.drop("Id",axis=1).boxplot(by="Species",figsize=(12,6))
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'PetalWidthCm'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'SepalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
from pandas.plotting import andrews_curves

# %%
from pandas.plotting import radviz
radviz(iris.drop("Id",axis=1),"Species")
# Out:
# <Axes: >
